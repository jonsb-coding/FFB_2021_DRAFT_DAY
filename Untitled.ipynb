# %%
import pandas as pd

# %%
passing_2020 = pd.read_csv("data/passing/passing_stats_2020.csv")
passing_2019 = pd.read_csv("data/passing/passing_stats_2019.csv")
passing_UDK = pd.read_csv("data/passing/passing_UDK.csv")
passing_2020.head()
# Out:
#    Year             Name Team Pos   G    QBR  COMP  PATT  COMP%  PYDS  ...  \
# 0  2020   Deshaun Watson  HOU  QB  16  112.4   382   544   70.2  4823  ...
# 1  2020  Patrick Mahomes   KC  QB  15  108.2   390   588   66.3  4740  ...
# 2  2020        Tom Brady   TB  QB  16  102.2   401   610   65.7  4633  ...
# 3  2020        Matt Ryan  ATL  QB  16   93.3   407   626   65.0  4581  ...
# 4  2020       Josh Allen  BUF  QB  16  107.2   396   572   69.2  4544  ...
#
#    Drops  Drop %  Avg YAC  INT  SCK  Sack %  FUM  RATT  RYDS  RTD
# 0     23     4.2      5.2    7   49     8.2    8    90   444    3
# 1     35     6.0      5.9    6   22     3.6    5    62   308    2
# 2     42     6.9      4.8   12   21     3.3    4    30     6    3
# 3     33     5.3      4.1   11   41     6.1    6    29    92    2
# 4     20     3.5      4.9   10   26     4.3    9   102   421    8
#
# [5 rows x 32 columns]

# %%
passing_2019.head()
# Out:
#    Year            Name Team Pos   G   QBR  COMP  PATT  COMP%  PYDS  ...  \
# 0  2019  Jameis Winston   TB  QB  16  84.3   380   626   60.7  5109  ...
# 1  2019    Dak Prescott  DAL  QB  16  99.7   388   596   65.1  4902  ...
# 2  2019      Jared Goff  LAR  QB  16  86.5   394   626   62.9  4638  ...
# 3  2019   Philip Rivers  LAC  QB  16  88.5   390   591   66.0  4615  ...
# 4  2019       Matt Ryan  ATL  QB  15  92.1   408   616   66.2  4466  ...
#
#    Drops  Drop %  Avg YAC  SCK  Sack %   FUM  RATT   RYDS  YPRA  RTD
# 0     27     4.3      5.4   47     7.0  12.0    59  250.0   4.2  1.0
# 1     43     7.2      5.1   23     3.7   6.0    52  277.0   5.3  3.0
# 2     27     4.3      5.9   22     3.4  10.0    33   40.0   1.2  2.0
# 3     26     4.4      5.8   34     5.4   8.0    12   29.0   2.4  0.0
# 4     22     3.6      4.2   48     7.2   9.0    34  147.0   4.3  1.0
#
# [5 rows x 33 columns]

# %%
passers = passing_UDK["Name"].values.tolist()
print(passers)
# Out:
# ['Kyler Murray', 'Patrick Mahomes', 'Lamar Jackson', 'Josh Allen', 'Dak Prescott', 'Aaron Rodgers', 'Tom Brady', 'Russell Wilson', 'Jalen Hurts', 'Taysom Hill', 'Justin Herbert', 'Ryan Tannehill', 'Carson Wentz', 'Kirk Cousins', 'Matt Ryan', 'Matthew Stafford', 'Trevor Lawrence', 'Joe Burrow', 'Ryan Fitzpatrick', 'Baker Mayfield', 'Derek Carr', 'Daniel Jones', 'Ben Roethlisberger', 'Tua Tagovailoa', 'Sam Darnold', 'Zach Wilson', 'Jared Goff', 'Teddy Bridgewater', 'Justin Fields', 'Tyrod Taylor', 'Cam Newton', 'Deshaun Watson', 'Trey Lance', 'Drew Lock', 'Jimmy Garoppolo', 'Mac Jones', 'Andy Dalton']

# %%
for names in passers:
# Out:
#   File "<ipython-input-5-83625b1fcf9a>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing
